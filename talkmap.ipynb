# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
# Out:
# Requirement already satisfied: getorg in /opt/anaconda3/lib/python3.12/site-packages (0.3.1)
# Requirement already satisfied: geopy in /opt/anaconda3/lib/python3.12/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /opt/anaconda3/lib/python3.12/site-packages (from getorg) (2.9.0)
# Requirement already satisfied: retrying in /opt/anaconda3/lib/python3.12/site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/anaconda3/lib/python3.12/site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pygithub->getorg) (1.6.2)
# Requirement already satisfied: requests>=2.14.0 in /opt/anaconda3/lib/python3.12/site-packages (from pygithub->getorg) (2.32.3)
# Requirement already satisfied: pyjwt>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.8.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from pygithub->getorg) (4.11.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pygithub->getorg) (2.2.3)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (43.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from pynacl>=1.4.0->pygithub->getorg) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (2024.8.30)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=2.0.0->pynacl>=1.4.0->pygithub->getorg) (2.21)
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
from geopy.geocoders import Nominatim

# %%
#g = glob.glob("*.md")
g = glob.glob("_talks/*.md")

# %%
geocoder = Nominatim(user_agent="talkmap", timeout=10)
from geopy.extra.rate_limiter import RateLimiter
geocode = RateLimiter(geocoder.geocode, min_delay_seconds=2)
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        #location_dict[location] = geocoder.geocode(location)
        location_dict[location] = geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# Seattle, WA
#  Seattle, King County, Washington, United States
# Chapel Hill, NC
#  Chapel Hill, Orange County, North Carolina, United States
# Virginia Tech, Blacksburg
#  Virginia Tech, 800, Drillfield Drive, Blacksburg, Montgomery County, Virginia, 24061, United States
# UNC-Chapel Hill, NC
#  University of North Carolina at Chapel Hill, Hawthorne Lane, Chapel Hill, Orange County, North Carolina, 27517, United States
# San Francisco, CA
#  San Francisco, California, United States
# Newark, New Jersey
#  Newark, Essex County, New Jersey, United States
# Tokyo, Japan
#  東京都, 日本
# Lincoln, NE
#  Lincoln, Lancaster County, Nebraska, United States
# San Marcos and Austin, TX
#  None
# Durham, NC
#  Durham, Durham County, North Carolina, United States
# UNC-Chapel Hill
#  University of North Carolina at Chapel Hill, Cheswick Court, Downtown, Carrboro, Orange County, North Carolina, 27510, United States
# Nashville, Tennessee
#  Nashville, Davidson County, Middle Tennessee, Tennessee, United States
# Atlanta, Georgia
#  Atlanta, Fulton County, Georgia, United States
# Baltimore, MD
#  Baltimore, Maryland, United States
# NC State University
#  North Carolina State University, Katharine Stinson Drive, Oberlin, Raleigh, Wake County, North Carolina, 27695, United States
# New York, NY
#  New York, United States
# Nashville, TN, USA
#  Nashville, Davidson County, Middle Tennessee, Tennessee, United States
# Alexandria, VA
#  Alexandria, Virginia, United States
# UNC-Chapel Hill
#  University of North Carolina at Chapel Hill, Cheswick Court, Downtown, Carrboro, Orange County, North Carolina, 27510, United States
# Seattle, WA
#  Seattle, King County, Washington, United States
# Java Center, NY
#  Java Center, Town of Java, Wyoming County, New York, 14082, United States
# NC State University
#  North Carolina State University, Katharine Stinson Drive, Oberlin, Raleigh, Wake County, North Carolina, 27695, United States
# Salt Lake City, UT
#  Salt Lake City, Salt Lake County, Utah, United States
# Java Center, NY
#  Java Center, Town of Java, Wyoming County, New York, 14082, United States
# Newark, New Jersey
#  Newark, Essex County, New Jersey, United States
# Brown University, Providence, RI
#  Brown University, Waterfront Drive, East Providence, Providence County, Rhode Island, 02912, United States
# Atlanta, Georgia
#  Atlanta, Fulton County, Georgia, United States

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
